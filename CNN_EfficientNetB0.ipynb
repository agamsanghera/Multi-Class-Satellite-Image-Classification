# %% [markdown]
# ## Setup
#
# Import the necessary libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import os
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import tensorflow_datasets as tfds
import glob
import shutil
import seaborn as sns
from sklearn.metrics import classification_report
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# Make new directories for the images to be put into various different classes and directories to save the models after training them, 3 models are created in this notebook

# %%
os.makedirs("ds_final_assignment/cloudy",exist_ok=True)
os.makedirs("ds_final_assignment/green_area",exist_ok=True)
os.makedirs("ds_final_assignment/desert",exist_ok=True)
os.makedirs("ds_final_assignment/water",exist_ok=True)
os.makedirs("models/m1",exist_ok=True)
os.makedirs("models/m2",exist_ok=True)
os.makedirs("models/m3",exist_ok=True)

# %% [markdown]
# Move images to the desired directory by detecting the classes based on the filenames

# %%
path = "ds_final_assignment/cloudy/"
path2="ds_final_assignment/desert"
path3="ds_final_assignment/water"
path4="ds_final_assignment/green_area"
files = glob.glob("ds_final_assignment/*cloudy*")
files2 = glob.glob("ds_final_assignment/*desert*")
files3 = glob.glob("ds_final_assignment/*water*")
files4 = glob.glob("ds_final_assignment/*green_area*")

for file in files:
    shutil.move(file, path)
for file2 in files2:
    shutil.move(file2, path2)
for file3 in files3:
    shutil.move(file3, path3)
for file4 in files4:
    shutil.move(file4, path4)

# %% [markdown]
# Assign the base directory where the dataset is stored including the home directory in this case directory is "D:\DataScience\ds_final_assignment". Please note that all the path creation and location assigning was done on a windows environment using python 3.10.9

# %%
from pathlib import Path
data_dir = Path(r"D:\DataScience\ds_final_assignment")

# %% [markdown]
# Count the images in the dataset

# %%
image_count = len(list(data_dir.glob('*\*.jpg')))
print(image_count)
# Out:
# 4200

# %% [markdown]
# Function to convert images of CMYK fromat into RGB

# %%
def conv(path):
    for x in path:
        image=PIL.Image.open(str(x))
        if image.mode == 'CMYK':
            image = image.convert('RGB')
            image.save(str(x))

# %% [markdown]
# Display an image from each class to check if the directory system is correctly installed

# %%
water = list(data_dir.glob('water/*'))
conv(water)
PIL.Image.open(str(water[7]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=64x64>

# %%
desert = list(data_dir.glob('desert/*'))
conv(desert)
PIL.Image.open(str(desert[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
green = list(data_dir.glob('green_area/*'))
conv(green)
PIL.Image.open(str(green[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=64x64>

# %%
cloudy = list(data_dir.glob('cloudy/*'))
conv(cloudy)
PIL.Image.open(str(cloudy[590]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# ## Load data using inbuilt dataloader utility
#
# Loaded images off disk using `tf.keras.utils.image_dataset_from_directory` utility.

# %% [markdown]
# ### Creating the dataset

# %% [markdown]
# Fix batches for training and resize images to 50*50 pixels as instructed

# %%
batch_size = 50
img_height = 50
img_width = 50

# %% [markdown]
# Split the dataset

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4200 files belonging to 4 classes.
# Using 3360 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4200 files belonging to 4 classes.
# Using 840 files for validation.

# %% [markdown]
# Display the class names using the `class_names` attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cloudy', 'desert', 'green_area', 'water']

# %% [markdown]
# ## Visualize the data
#
# Here are the first nine images from the training dataset, these were obtained using the take() function of the PrefetchDataset object as the images can not be directly viewed otherwise. These images were then displyed using the matplotlib imshow() function

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The shape of the image and label batches are displayed below, directly iterating over the PrefetchDataset object gives the batches of images and labels

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (50, 50, 50, 3)
# (50,)

# %% [markdown]
# ## Preprocessing the dataset
#
# Used buffered prefetching, to yield data from disk without having I/O blocking. The following methods were used when loading data:
#
# - `Dataset.cache` to keep the images in memory after loading from the disk during the first epoch. This is done to ensure that the dataset does not become a bottleneck while training the models.
# - `Dataset.prefetch` overlaps data preprocessing and model execution while training.
#
#
# The number of elements to prefetch should be equal to (or possibly greater than) the number of batches consumed by a single training step. tf.data.AUTOTUNE does this job

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standardizing data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network; thus normalize the values between  `[0, 1]` range by using `tf.keras.layers.Rescaling`:

# %%
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# ## Model1
#
# ### Create the model
#
# The Keras Sequential model consists of three convolution blocks (`tf.keras.layers.Conv2D`) with a max pooling layer (`tf.keras.layers.MaxPooling2D`) in each of them. There's a fully-connected layer (`tf.keras.layers.Dense`) with 128 units on top of it that is activated by a ReLU activation function (`'relu'`).

# %%
num_classes = len(class_names)

model1 = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
#
# The `tf.keras.optimizers.Adam` optimizer and `tf.keras.losses.SparseCategoricalCrossentropy` loss function were chosen, and training and validation accuracy for each training epoch were calculated by passing the `metrics` argument to `model1.compile`.

# %%
model1.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Model summary
#
# View all the layers of the network using the Keras `Model.summary` method:

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 50, 50, 3)         0
#
#  conv2d (Conv2D)             (None, 50, 50, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 319,140
# Trainable params: 319,140
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %% [markdown]
# Trained the model for 100 epochs with the Keras `Model.fit` method:

# %%
epochs=100
history1 = model1.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/100
# 68/68 [==============================] - 4s 45ms/step - loss: 0.6134 - accuracy: 0.7057 - val_loss: 0.4675 - val_accuracy: 0.7738
# Epoch 2/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.4715 - accuracy: 0.7643 - val_loss: 0.4392 - val_accuracy: 0.7988
# Epoch 3/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.3999 - accuracy: 0.8265 - val_loss: 0.3269 - val_accuracy: 0.8714
# Epoch 4/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.3463 - accuracy: 0.8503 - val_loss: 0.3253 - val_accuracy: 0.8500
# Epoch 5/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.2894 - accuracy: 0.8765 - val_loss: 0.3170 - val_accuracy: 0.8417
# Epoch 6/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2936 - accuracy: 0.8738 - val_loss: 0.2729 - val_accuracy: 0.8679
# Epoch 7/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.3167 - accuracy: 0.8667 - val_loss: 0.3966 - val_accuracy: 0.8452
# Epoch 8/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2738 - accuracy: 0.8866 - val_loss: 0.2713 - val_accuracy: 0.8845
# Epoch 9/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.2384 - accuracy: 0.9057 - val_loss: 0.2935 - val_accuracy: 0.8786
# Epoch 10/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.2247 - accuracy: 0.9104 - val_loss: 0.2320 - val_accuracy: 0.9107
# Epoch 11/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.2290 - accuracy: 0.9074 - val_loss: 0.2310 - val_accuracy: 0.9083
# Epoch 12/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2177 - accuracy: 0.9173 - val_loss: 0.2387 - val_accuracy: 0.9024
# Epoch 13/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2278 - accuracy: 0.9101 - val_loss: 0.2482 - val_accuracy: 0.8917
# Epoch 14/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.2079 - accuracy: 0.9170 - val_loss: 0.2755 - val_accuracy: 0.9036
# Epoch 15/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2013 - accuracy: 0.9247 - val_loss: 0.2277 - val_accuracy: 0.9000
# Epoch 16/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.2629 - accuracy: 0.8899 - val_loss: 0.2690 - val_accuracy: 0.8893
# Epoch 17/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2105 - accuracy: 0.9152 - val_loss: 0.2935 - val_accuracy: 0.8810
# Epoch 18/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.2081 - accuracy: 0.9158 - val_loss: 0.2103 - val_accuracy: 0.9238
# Epoch 19/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2029 - accuracy: 0.9199 - val_loss: 0.2186 - val_accuracy: 0.9048
# Epoch 20/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.1930 - accuracy: 0.9229 - val_loss: 0.2051 - val_accuracy: 0.9155
# Epoch 21/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.1726 - accuracy: 0.9363 - val_loss: 0.1874 - val_accuracy: 0.9357
# Epoch 22/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.2024 - accuracy: 0.9155 - val_loss: 0.3200 - val_accuracy: 0.8548
# Epoch 23/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1797 - accuracy: 0.9298 - val_loss: 0.2984 - val_accuracy: 0.8524
# Epoch 24/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2042 - accuracy: 0.9143 - val_loss: 0.1745 - val_accuracy: 0.9429
# Epoch 25/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1974 - accuracy: 0.9211 - val_loss: 0.1806 - val_accuracy: 0.9333
# Epoch 26/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1603 - accuracy: 0.9363 - val_loss: 0.1751 - val_accuracy: 0.9298
# Epoch 27/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.1697 - accuracy: 0.9375 - val_loss: 0.1882 - val_accuracy: 0.9238
# Epoch 28/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.1433 - accuracy: 0.9464 - val_loss: 0.1860 - val_accuracy: 0.9262
# Epoch 29/100
# 68/68 [==============================] - 3s 40ms/step - loss: 0.1538 - accuracy: 0.9449 - val_loss: 0.1613 - val_accuracy: 0.9345
# Epoch 30/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1963 - accuracy: 0.9208 - val_loss: 0.1642 - val_accuracy: 0.9369
# Epoch 31/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1283 - accuracy: 0.9500 - val_loss: 0.1425 - val_accuracy: 0.9464
# Epoch 32/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.1563 - accuracy: 0.9381 - val_loss: 0.1687 - val_accuracy: 0.9310
# Epoch 33/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1442 - accuracy: 0.9479 - val_loss: 0.1785 - val_accuracy: 0.9429
# Epoch 34/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.1417 - accuracy: 0.9443 - val_loss: 0.1572 - val_accuracy: 0.9405
# Epoch 35/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.1332 - accuracy: 0.9503 - val_loss: 0.1509 - val_accuracy: 0.9321
# Epoch 36/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.1224 - accuracy: 0.9557 - val_loss: 0.1543 - val_accuracy: 0.9476
# Epoch 37/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1127 - accuracy: 0.9583 - val_loss: 0.1378 - val_accuracy: 0.9583
# Epoch 38/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1451 - accuracy: 0.9455 - val_loss: 0.2833 - val_accuracy: 0.8702
# Epoch 39/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.1301 - accuracy: 0.9539 - val_loss: 0.1341 - val_accuracy: 0.9440
# Epoch 40/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.1236 - accuracy: 0.9554 - val_loss: 0.1610 - val_accuracy: 0.9440
# Epoch 41/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1346 - accuracy: 0.9503 - val_loss: 0.2080 - val_accuracy: 0.9202
# Epoch 42/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0968 - accuracy: 0.9693 - val_loss: 0.1475 - val_accuracy: 0.9464
# Epoch 43/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1025 - accuracy: 0.9643 - val_loss: 0.1033 - val_accuracy: 0.9595
# Epoch 44/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1000 - accuracy: 0.9610 - val_loss: 0.1306 - val_accuracy: 0.9524
# Epoch 45/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.1100 - accuracy: 0.9604 - val_loss: 0.1051 - val_accuracy: 0.9679
# Epoch 46/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.1335 - accuracy: 0.9503 - val_loss: 0.1328 - val_accuracy: 0.9512
# Epoch 47/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1009 - accuracy: 0.9664 - val_loss: 0.1289 - val_accuracy: 0.9619
# Epoch 48/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1379 - accuracy: 0.9479 - val_loss: 0.2593 - val_accuracy: 0.8857
# Epoch 49/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1412 - accuracy: 0.9449 - val_loss: 0.1064 - val_accuracy: 0.9583
# Epoch 50/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.0785 - accuracy: 0.9732 - val_loss: 0.1190 - val_accuracy: 0.9560
# Epoch 51/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0908 - accuracy: 0.9699 - val_loss: 0.1226 - val_accuracy: 0.9655
# Epoch 52/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.0810 - accuracy: 0.9717 - val_loss: 0.1848 - val_accuracy: 0.9429
# Epoch 53/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0730 - accuracy: 0.9753 - val_loss: 0.1615 - val_accuracy: 0.9524
# Epoch 54/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.0990 - accuracy: 0.9646 - val_loss: 0.1169 - val_accuracy: 0.9607
# Epoch 55/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.1062 - accuracy: 0.9652 - val_loss: 0.0926 - val_accuracy: 0.9679
# Epoch 56/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.0857 - accuracy: 0.9696 - val_loss: 0.1580 - val_accuracy: 0.9583
# Epoch 57/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.0919 - accuracy: 0.9679 - val_loss: 0.0855 - val_accuracy: 0.9738
# Epoch 58/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.0725 - accuracy: 0.9741 - val_loss: 0.1067 - val_accuracy: 0.9607
# Epoch 59/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.0755 - accuracy: 0.9741 - val_loss: 0.2234 - val_accuracy: 0.9048
# Epoch 60/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.0860 - accuracy: 0.9705 - val_loss: 0.2262 - val_accuracy: 0.8964
# Epoch 61/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.1014 - accuracy: 0.9607 - val_loss: 0.1047 - val_accuracy: 0.9619
# Epoch 62/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.0739 - accuracy: 0.9753 - val_loss: 0.1189 - val_accuracy: 0.9583
# Epoch 63/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.0846 - accuracy: 0.9714 - val_loss: 0.1388 - val_accuracy: 0.9369
# Epoch 64/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0593 - accuracy: 0.9804 - val_loss: 0.0841 - val_accuracy: 0.9702
# Epoch 65/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0784 - accuracy: 0.9714 - val_loss: 0.0834 - val_accuracy: 0.9750
# Epoch 66/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.0704 - accuracy: 0.9789 - val_loss: 0.0898 - val_accuracy: 0.9690
# Epoch 67/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.0753 - accuracy: 0.9762 - val_loss: 0.0727 - val_accuracy: 0.9774
# Epoch 68/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.0619 - accuracy: 0.9807 - val_loss: 0.1084 - val_accuracy: 0.9619
# Epoch 69/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0580 - accuracy: 0.9839 - val_loss: 0.0747 - val_accuracy: 0.9714
# Epoch 70/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0563 - accuracy: 0.9792 - val_loss: 0.0826 - val_accuracy: 0.9667
# Epoch 71/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.0499 - accuracy: 0.9845 - val_loss: 0.0736 - val_accuracy: 0.9726
# Epoch 72/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.0689 - accuracy: 0.9768 - val_loss: 0.0947 - val_accuracy: 0.9607
# Epoch 73/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.0721 - accuracy: 0.9738 - val_loss: 0.1052 - val_accuracy: 0.9690
# Epoch 74/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.0640 - accuracy: 0.9774 - val_loss: 0.0731 - val_accuracy: 0.9750
# Epoch 75/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0432 - accuracy: 0.9854 - val_loss: 0.1150 - val_accuracy: 0.9619
# Epoch 76/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.0779 - accuracy: 0.9738 - val_loss: 0.0799 - val_accuracy: 0.9738
# Epoch 77/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0565 - accuracy: 0.9842 - val_loss: 0.1257 - val_accuracy: 0.9524
# Epoch 78/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0576 - accuracy: 0.9830 - val_loss: 0.1150 - val_accuracy: 0.9571
# Epoch 79/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0511 - accuracy: 0.9821 - val_loss: 0.1142 - val_accuracy: 0.9571
# Epoch 80/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.1079 - accuracy: 0.9604 - val_loss: 0.1438 - val_accuracy: 0.9500
# Epoch 81/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.0702 - accuracy: 0.9777 - val_loss: 0.0954 - val_accuracy: 0.9702
# Epoch 82/100
# 68/68 [==============================] - 3s 48ms/step - loss: 0.0545 - accuracy: 0.9833 - val_loss: 0.0681 - val_accuracy: 0.9726
# Epoch 83/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.0374 - accuracy: 0.9890 - val_loss: 0.0585 - val_accuracy: 0.9798
# Epoch 84/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.0622 - accuracy: 0.9798 - val_loss: 0.1881 - val_accuracy: 0.9345
# Epoch 85/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.0484 - accuracy: 0.9842 - val_loss: 0.1001 - val_accuracy: 0.9667
# Epoch 86/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0529 - accuracy: 0.9827 - val_loss: 0.0686 - val_accuracy: 0.9786
# Epoch 87/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.0597 - accuracy: 0.9818 - val_loss: 0.1348 - val_accuracy: 0.9560
# Epoch 88/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0594 - accuracy: 0.9789 - val_loss: 0.0779 - val_accuracy: 0.9774
# Epoch 89/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.0454 - accuracy: 0.9839 - val_loss: 0.0594 - val_accuracy: 0.9786
# Epoch 90/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0333 - accuracy: 0.9884 - val_loss: 0.0840 - val_accuracy: 0.9750
# Epoch 91/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.0322 - accuracy: 0.9890 - val_loss: 0.0772 - val_accuracy: 0.9738
# Epoch 92/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0347 - accuracy: 0.9887 - val_loss: 0.0837 - val_accuracy: 0.9786
# Epoch 93/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.0527 - accuracy: 0.9812 - val_loss: 0.1583 - val_accuracy: 0.9405
# Epoch 94/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0500 - accuracy: 0.9836 - val_loss: 0.0897 - val_accuracy: 0.9738
# Epoch 95/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0285 - accuracy: 0.9917 - val_loss: 0.0967 - val_accuracy: 0.9702
# Epoch 96/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0482 - accuracy: 0.9845 - val_loss: 0.0517 - val_accuracy: 0.9857
# Epoch 97/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0447 - accuracy: 0.9839 - val_loss: 0.0908 - val_accuracy: 0.9631
# Epoch 98/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0351 - accuracy: 0.9881 - val_loss: 0.1146 - val_accuracy: 0.9726
# Epoch 99/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.0253 - accuracy: 0.9914 - val_loss: 0.1083 - val_accuracy: 0.9548
# Epoch 100/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2052 - accuracy: 0.9351 - val_loss: 0.1795 - val_accuracy: 0.9452

# %% [markdown]
# ## Visualize training results

# %% [markdown]
# Create plots of the loss and accuracy on the training and validation sets:

# %%
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']

loss = history1.history['loss']
val_loss = history1.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(20, 20))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Functions for plotting Confusion Matrix

# %% [markdown]
# First get the actual labels saved in the dataset, in thes case of this notebook train_ds and val_ds are used to save the training and validation datasets respectively.
# dataset.unbatch() utility of the PrefetcheDataset type is used to obtain actual labels and the predicted labels are then predicted using the predict function of the model, these are then concatenated and the arg max is taken as the data is stored as a tensor

# %%
def get_actual_predicted_labels(dataset,model): 
  """
    Create a list of actual ground truth values and the predictions from the model.

    Args:
      dataset: An iterable data structure, such as a TensorFlow Dataset, with features and labels.

    Return:
      Ground truth and predicted values for a particular dataset.
  """
  actual = [labels for _, labels in dataset.unbatch()]
  predicted = model.predict(dataset)

  actual = tf.stack(actual, axis=0)
  predicted = tf.concat(predicted, axis=0)
  predicted = tf.argmax(predicted, axis=1)

  return actual, predicted

# %% [markdown]
# Create the function to plot a confusion matrix using the actual and predicted labels

# %%
def plot_confusion_matrix(actual, predicted, labels, ds_type):
  cm = tf.math.confusion_matrix(actual, predicted)
  ax = sns.heatmap(cm, annot=True, fmt='g',cmap="Blues")
  sns.set(rc={'figure.figsize':(12, 12)})
  sns.set(font_scale=1.4)
  ax.set_title('Confusion matrix of classifaction ' + ds_type)
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('Actual labels')
  plt.xticks(rotation=90)
  plt.yticks(rotation=0)
  ax.xaxis.set_ticklabels(labels)
  ax.yaxis.set_ticklabels(labels)

# %% [markdown]
# Predict the data on the validation set and plot against the actual labels obtained previously to form the confusion matrix

# %%
actuals,preds=get_actual_predicted_labels(val_ds,model1)
plot_confusion_matrix(actuals,preds,class_names,'Validation')
# Out:
# 17/17 [==============================] - 0s 9ms/step

# %% [markdown]
# Print the name of the model, accuracy, class-wise precision, recall, and F1 score.

# %%
print(
    f"Classification report for classifier {model1}:\n"
    f"{classification_report(actuals,preds)}\n"
)
# Out:
# Classification report for classifier <keras.engine.sequential.Sequential object at 0x0000021E371F2920>:
#               precision    recall  f1-score   support
#
#            0       0.99      0.83      0.90       169
#            1       0.90      0.99      0.94       218
#            2       0.95      0.94      0.94       154
#            3       0.96      0.98      0.97       299
#
#     accuracy                           0.95       840
#    macro avg       0.95      0.94      0.94       840
# weighted avg       0.95      0.95      0.94       840

# %% [markdown]
# Save the model to device in the directory created previously to prevent the need for retraining the model

# %%
model1.save('model/m1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model/m1\assets
# INFO:tensorflow:Assets written to: model/m1\assets

# %% [markdown]
# The plots show that training accuracy and validation accuracy are off by large margins, and the model has achieved only around 60% accuracy on the validation set.
#
# The following tutorial sections show how to inspect what went wrong and try to increase the overall performance of the model.

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# Data augmentation was implemented using the following Keras preprocessing layers: `tf.keras.layers.RandomZoom`, `tf.keras.layers.GuassianNoise`, and `tf.keras.layers.RandomRotation`.

# %%
data_augmentation = keras.Sequential(
  [
    layers.GaussianNoise(stddev=0.1,input_shape=(img_height,img_width,3)),
    layers.RandomRotation(0.3),
    layers.RandomZoom(0.1),
  ]
)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# Visualize a few augmented examples by applying data augmentation to the same image several times:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# Data augmentation will be added to the model before training in the next step.

# %% [markdown]
# ## Dropout
#
# Another technique to reduce overfitting is to introduce dropout regularization to the network.
#
# By applying dropout to a layer, it randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.

# %%
model2 = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %% [markdown]
# ## Compile and train the model

# %%
model2.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 50, 50, 3)         0
#
#  rescaling_2 (Rescaling)     (None, 50, 50, 3)         0
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 16)        448
#
#  max_pooling2d_3 (MaxPooling  (None, 25, 25, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 6, 6, 64)          0
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_2 (Dense)             (None, 128)               295040
#
#  outputs (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 319,140
# Trainable params: 319,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
history2 = model2.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 68/68 [==============================] - 7s 56ms/step - loss: 0.6744 - accuracy: 0.6807 - val_loss: 0.4898 - val_accuracy: 0.7643
# Epoch 2/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.4074 - accuracy: 0.8000 - val_loss: 0.4855 - val_accuracy: 0.7869
# Epoch 3/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.3769 - accuracy: 0.8292 - val_loss: 0.3882 - val_accuracy: 0.8155
# Epoch 4/100
# 68/68 [==============================] - 4s 61ms/step - loss: 0.3721 - accuracy: 0.8313 - val_loss: 0.4093 - val_accuracy: 0.8083
# Epoch 5/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.3514 - accuracy: 0.8446 - val_loss: 0.3447 - val_accuracy: 0.8571
# Epoch 6/100
# 68/68 [==============================] - 4s 54ms/step - loss: 0.3118 - accuracy: 0.8643 - val_loss: 0.4222 - val_accuracy: 0.8131
# Epoch 7/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.3077 - accuracy: 0.8634 - val_loss: 0.3008 - val_accuracy: 0.8488
# Epoch 8/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.2990 - accuracy: 0.8732 - val_loss: 0.3540 - val_accuracy: 0.8381
# Epoch 9/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.2935 - accuracy: 0.8774 - val_loss: 0.2758 - val_accuracy: 0.8774
# Epoch 10/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.2830 - accuracy: 0.8771 - val_loss: 0.3250 - val_accuracy: 0.8560
# Epoch 11/100
# 68/68 [==============================] - 4s 54ms/step - loss: 0.3014 - accuracy: 0.8774 - val_loss: 0.4024 - val_accuracy: 0.8048
# Epoch 12/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.2833 - accuracy: 0.8765 - val_loss: 0.2811 - val_accuracy: 0.8869
# Epoch 13/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.2583 - accuracy: 0.8938 - val_loss: 0.2489 - val_accuracy: 0.9012
# Epoch 14/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.2692 - accuracy: 0.8848 - val_loss: 0.2753 - val_accuracy: 0.8869
# Epoch 15/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.2837 - accuracy: 0.8738 - val_loss: 0.2773 - val_accuracy: 0.9083
# Epoch 16/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.2649 - accuracy: 0.8917 - val_loss: 0.2955 - val_accuracy: 0.8774
# Epoch 17/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.2577 - accuracy: 0.8949 - val_loss: 0.2417 - val_accuracy: 0.9107
# Epoch 18/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.2305 - accuracy: 0.9119 - val_loss: 0.2513 - val_accuracy: 0.9131
# Epoch 19/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.2206 - accuracy: 0.9107 - val_loss: 0.2374 - val_accuracy: 0.8905
# Epoch 20/100
# 68/68 [==============================] - 4s 61ms/step - loss: 0.2214 - accuracy: 0.9065 - val_loss: 0.2457 - val_accuracy: 0.9071
# Epoch 21/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.2371 - accuracy: 0.9009 - val_loss: 0.2254 - val_accuracy: 0.9024
# Epoch 22/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.2099 - accuracy: 0.9089 - val_loss: 0.2365 - val_accuracy: 0.9036
# Epoch 23/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.2066 - accuracy: 0.9173 - val_loss: 0.2564 - val_accuracy: 0.8893
# Epoch 24/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.2370 - accuracy: 0.8988 - val_loss: 0.2565 - val_accuracy: 0.9071
# Epoch 25/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.2207 - accuracy: 0.9128 - val_loss: 0.2064 - val_accuracy: 0.9155
# Epoch 26/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.2159 - accuracy: 0.9080 - val_loss: 0.2829 - val_accuracy: 0.8619
# Epoch 27/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.2411 - accuracy: 0.9003 - val_loss: 0.2402 - val_accuracy: 0.8845
# Epoch 28/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.2122 - accuracy: 0.9107 - val_loss: 0.2313 - val_accuracy: 0.8976
# Epoch 29/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.2121 - accuracy: 0.9161 - val_loss: 0.2136 - val_accuracy: 0.9167
# Epoch 30/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1914 - accuracy: 0.9235 - val_loss: 0.2187 - val_accuracy: 0.9167
# Epoch 31/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1914 - accuracy: 0.9220 - val_loss: 0.2190 - val_accuracy: 0.9095
# Epoch 32/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.1859 - accuracy: 0.9229 - val_loss: 0.3271 - val_accuracy: 0.8655
# Epoch 33/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.2078 - accuracy: 0.9238 - val_loss: 0.2296 - val_accuracy: 0.8952
# Epoch 34/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.1972 - accuracy: 0.9164 - val_loss: 0.2383 - val_accuracy: 0.9071
# Epoch 35/100
# 68/68 [==============================] - 4s 62ms/step - loss: 0.2074 - accuracy: 0.9110 - val_loss: 0.2086 - val_accuracy: 0.9226
# Epoch 36/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.1729 - accuracy: 0.9333 - val_loss: 0.1841 - val_accuracy: 0.9262
# Epoch 37/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1869 - accuracy: 0.9262 - val_loss: 0.2163 - val_accuracy: 0.9048
# Epoch 38/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1733 - accuracy: 0.9292 - val_loss: 0.2277 - val_accuracy: 0.8952
# Epoch 39/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1833 - accuracy: 0.9298 - val_loss: 0.2014 - val_accuracy: 0.9107
# Epoch 40/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1820 - accuracy: 0.9247 - val_loss: 0.2692 - val_accuracy: 0.8798
# Epoch 41/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1762 - accuracy: 0.9298 - val_loss: 0.2415 - val_accuracy: 0.9131
# Epoch 42/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.1690 - accuracy: 0.9304 - val_loss: 0.2482 - val_accuracy: 0.8881
# Epoch 43/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.1760 - accuracy: 0.9336 - val_loss: 0.2541 - val_accuracy: 0.8988
# Epoch 44/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1634 - accuracy: 0.9378 - val_loss: 0.1755 - val_accuracy: 0.9262
# Epoch 45/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1690 - accuracy: 0.9348 - val_loss: 0.2332 - val_accuracy: 0.8762
# Epoch 46/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1789 - accuracy: 0.9298 - val_loss: 0.1856 - val_accuracy: 0.9238
# Epoch 47/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1925 - accuracy: 0.9235 - val_loss: 0.2116 - val_accuracy: 0.9048
# Epoch 48/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1566 - accuracy: 0.9378 - val_loss: 0.1634 - val_accuracy: 0.9238
# Epoch 49/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1675 - accuracy: 0.9307 - val_loss: 0.1756 - val_accuracy: 0.9250
# Epoch 50/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.1697 - accuracy: 0.9324 - val_loss: 0.2027 - val_accuracy: 0.9274
# Epoch 51/100
# 68/68 [==============================] - 4s 61ms/step - loss: 0.1659 - accuracy: 0.9348 - val_loss: 0.1705 - val_accuracy: 0.9310
# Epoch 52/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1421 - accuracy: 0.9458 - val_loss: 0.2257 - val_accuracy: 0.9107
# Epoch 53/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1613 - accuracy: 0.9336 - val_loss: 0.2185 - val_accuracy: 0.9095
# Epoch 54/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1764 - accuracy: 0.9315 - val_loss: 0.1724 - val_accuracy: 0.9369
# Epoch 55/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1579 - accuracy: 0.9363 - val_loss: 0.1811 - val_accuracy: 0.9214
# Epoch 56/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1407 - accuracy: 0.9458 - val_loss: 0.1397 - val_accuracy: 0.9464
# Epoch 57/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1732 - accuracy: 0.9312 - val_loss: 0.1656 - val_accuracy: 0.9310
# Epoch 58/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1796 - accuracy: 0.9289 - val_loss: 0.2609 - val_accuracy: 0.9214
# Epoch 59/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1640 - accuracy: 0.9363 - val_loss: 0.1506 - val_accuracy: 0.9524
# Epoch 60/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1445 - accuracy: 0.9449 - val_loss: 0.1945 - val_accuracy: 0.9262
# Epoch 61/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1475 - accuracy: 0.9411 - val_loss: 0.1888 - val_accuracy: 0.9417
# Epoch 62/100
# 68/68 [==============================] - 4s 54ms/step - loss: 0.1566 - accuracy: 0.9378 - val_loss: 0.1454 - val_accuracy: 0.9429
# Epoch 63/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1494 - accuracy: 0.9443 - val_loss: 0.1841 - val_accuracy: 0.9381
# Epoch 64/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1425 - accuracy: 0.9446 - val_loss: 0.1519 - val_accuracy: 0.9369
# Epoch 65/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1388 - accuracy: 0.9446 - val_loss: 0.1368 - val_accuracy: 0.9452
# Epoch 66/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.1680 - accuracy: 0.9378 - val_loss: 0.1702 - val_accuracy: 0.9226
# Epoch 67/100
# 68/68 [==============================] - 4s 59ms/step - loss: 0.1392 - accuracy: 0.9458 - val_loss: 0.1510 - val_accuracy: 0.9298
# Epoch 68/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.1317 - accuracy: 0.9512 - val_loss: 0.1587 - val_accuracy: 0.9262
# Epoch 69/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1226 - accuracy: 0.9568 - val_loss: 0.1459 - val_accuracy: 0.9262
# Epoch 70/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1287 - accuracy: 0.9515 - val_loss: 0.1391 - val_accuracy: 0.9417
# Epoch 71/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1377 - accuracy: 0.9503 - val_loss: 0.1639 - val_accuracy: 0.9345
# Epoch 72/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1348 - accuracy: 0.9479 - val_loss: 0.1188 - val_accuracy: 0.9548
# Epoch 73/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1486 - accuracy: 0.9455 - val_loss: 0.1496 - val_accuracy: 0.9405
# Epoch 74/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1334 - accuracy: 0.9467 - val_loss: 0.1424 - val_accuracy: 0.9536
# Epoch 75/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1245 - accuracy: 0.9551 - val_loss: 0.1215 - val_accuracy: 0.9500
# Epoch 76/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1122 - accuracy: 0.9595 - val_loss: 0.1655 - val_accuracy: 0.9286
# Epoch 77/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1226 - accuracy: 0.9506 - val_loss: 0.1092 - val_accuracy: 0.9500
# Epoch 78/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.1377 - accuracy: 0.9485 - val_loss: 0.1511 - val_accuracy: 0.9405
# Epoch 79/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1219 - accuracy: 0.9563 - val_loss: 0.1259 - val_accuracy: 0.9583
# Epoch 80/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1445 - accuracy: 0.9423 - val_loss: 0.1401 - val_accuracy: 0.9429
# Epoch 81/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.1150 - accuracy: 0.9580 - val_loss: 0.1232 - val_accuracy: 0.9464
# Epoch 82/100
# 68/68 [==============================] - 4s 60ms/step - loss: 0.1071 - accuracy: 0.9583 - val_loss: 0.1168 - val_accuracy: 0.9583
# Epoch 83/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0959 - accuracy: 0.9628 - val_loss: 0.1028 - val_accuracy: 0.9643
# Epoch 84/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1003 - accuracy: 0.9625 - val_loss: 0.1482 - val_accuracy: 0.9369
# Epoch 85/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1661 - accuracy: 0.9354 - val_loss: 0.1384 - val_accuracy: 0.9595
# Epoch 86/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1360 - accuracy: 0.9515 - val_loss: 0.1211 - val_accuracy: 0.9536
# Epoch 87/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.1020 - accuracy: 0.9619 - val_loss: 0.0874 - val_accuracy: 0.9714
# Epoch 88/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1154 - accuracy: 0.9565 - val_loss: 0.1381 - val_accuracy: 0.9429
# Epoch 89/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.0975 - accuracy: 0.9625 - val_loss: 0.1742 - val_accuracy: 0.9250
# Epoch 90/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1155 - accuracy: 0.9563 - val_loss: 0.1877 - val_accuracy: 0.9274
# Epoch 91/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.1099 - accuracy: 0.9595 - val_loss: 0.1537 - val_accuracy: 0.9333
# Epoch 92/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1225 - accuracy: 0.9554 - val_loss: 0.1786 - val_accuracy: 0.9298
# Epoch 93/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1072 - accuracy: 0.9595 - val_loss: 0.1046 - val_accuracy: 0.9583
# Epoch 94/100
# 68/68 [==============================] - 4s 55ms/step - loss: 0.0928 - accuracy: 0.9670 - val_loss: 0.1140 - val_accuracy: 0.9476
# Epoch 95/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.1025 - accuracy: 0.9619 - val_loss: 0.1078 - val_accuracy: 0.9655
# Epoch 96/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.0984 - accuracy: 0.9619 - val_loss: 0.1164 - val_accuracy: 0.9488
# Epoch 97/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.1056 - accuracy: 0.9598 - val_loss: 0.0970 - val_accuracy: 0.9655
# Epoch 98/100
# 68/68 [==============================] - 4s 62ms/step - loss: 0.0844 - accuracy: 0.9679 - val_loss: 0.0892 - val_accuracy: 0.9631
# Epoch 99/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.0980 - accuracy: 0.9619 - val_loss: 0.1569 - val_accuracy: 0.9393
# Epoch 100/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.1044 - accuracy: 0.9634 - val_loss: 0.1405 - val_accuracy: 0.9417

# %% [markdown]
# ## Visualize training results

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']

loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(30, 20))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Save model2

# %%
model2.save('model/m2')

# %% [markdown]
#  Plot confusion matrix for model2

# %%
actual,predicted=get_actual_predicted_labels(val_ds,model2)
plot_confusion_matrix(actual,predicted,class_names,'Validation')
# Out:
# 17/17 [==============================] - 0s 11ms/step

# %% [markdown]
# Print the name of the model, accuracy, class-wise precision, recall, and F1 score.

# %%
print(
    f"Classification report for classifier {model2}:\n"
    f"{classification_report(actual,predicted)}\n"
)
# Out:
# Classification report for classifier <keras.engine.sequential.Sequential object at 0x0000021E42001DE0>:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       169
#            1       0.97      0.98      0.97       218
#            2       0.81      1.00      0.90       154
#            3       1.00      0.88      0.93       299
#
#     accuracy                           0.94       840
#    macro avg       0.94      0.95      0.94       840
# weighted avg       0.95      0.94      0.94       840

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# Transfer Learning is the process of using the knowledge obtained from learning a specific task and then applying it to another similar task so that lesser resources are wasted in retraining models from scratch

# %% [markdown]
# In this notebook the model `EfficientNetB0` is retrained without the weights, by just using the architecture on the dataset along with a `GlobalAveragePooling` layer and a `Dense` layer to classify the images correctly among 4 classes

# %%
base_model = tf.keras.applications.EfficientNetB0(weights=None, include_top=False, input_shape=(img_height,img_width) + (3,))

model3=Sequential([ 
  base_model,
  layers.GlobalAveragePooling2D(),
  layers.Dense(num_classes, activation='softmax',name="outputs")
  #layers.Dense(num_classes, name="outputs")
])

# %% [markdown]
# ## Compile the model3

# %%
model3.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 2, 2, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  outputs (Dense)             (None, 4)                 5124
#
# =================================================================
# Total params: 4,054,695
# Trainable params: 4,012,672
# Non-trainable params: 42,023
# _________________________________________________________________

# %% [markdown]
# Only ran 50 epochs as the processing time was very high due to a large number of trainable parameters

# %%
epochs = 50
history3 = model3.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# C:\Users\agams\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 68/68 [==============================] - 45s 371ms/step - loss: 0.6891 - accuracy: 0.7348 - val_loss: 1.5009 - val_accuracy: 0.3560
# Epoch 2/50
# 68/68 [==============================] - 25s 361ms/step - loss: 0.3866 - accuracy: 0.8592 - val_loss: 1.4316 - val_accuracy: 0.3560
# Epoch 3/50
# 68/68 [==============================] - 24s 356ms/step - loss: 0.3318 - accuracy: 0.8744 - val_loss: 1.5163 - val_accuracy: 0.3560
# Epoch 4/50
# 68/68 [==============================] - 24s 357ms/step - loss: 0.2181 - accuracy: 0.9226 - val_loss: 1.4940 - val_accuracy: 0.3560
# Epoch 5/50
# 68/68 [==============================] - 24s 354ms/step - loss: 0.1638 - accuracy: 0.9458 - val_loss: 1.4370 - val_accuracy: 0.3881
# Epoch 6/50
# 68/68 [==============================] - 24s 353ms/step - loss: 0.1346 - accuracy: 0.9545 - val_loss: 1.4792 - val_accuracy: 0.5512
# Epoch 7/50
# 68/68 [==============================] - 24s 357ms/step - loss: 0.0944 - accuracy: 0.9673 - val_loss: 1.5110 - val_accuracy: 0.4964
# Epoch 8/50
# 68/68 [==============================] - 24s 352ms/step - loss: 0.1032 - accuracy: 0.9658 - val_loss: 0.8484 - val_accuracy: 0.6071
# Epoch 9/50
# 68/68 [==============================] - 24s 353ms/step - loss: 0.0563 - accuracy: 0.9798 - val_loss: 0.9172 - val_accuracy: 0.7857
# Epoch 10/50
# 68/68 [==============================] - 24s 359ms/step - loss: 0.0573 - accuracy: 0.9839 - val_loss: 0.3309 - val_accuracy: 0.9000
# Epoch 11/50
# 68/68 [==============================] - 24s 352ms/step - loss: 0.0542 - accuracy: 0.9869 - val_loss: 0.4587 - val_accuracy: 0.8417
# Epoch 12/50
# 68/68 [==============================] - 24s 360ms/step - loss: 0.0854 - accuracy: 0.9711 - val_loss: 0.3698 - val_accuracy: 0.9060
# Epoch 13/50
# 68/68 [==============================] - 25s 365ms/step - loss: 0.0599 - accuracy: 0.9804 - val_loss: 0.2550 - val_accuracy: 0.9250
# Epoch 14/50
# 68/68 [==============================] - 25s 362ms/step - loss: 0.0686 - accuracy: 0.9798 - val_loss: 0.1511 - val_accuracy: 0.9440
# Epoch 15/50
# 68/68 [==============================] - 25s 366ms/step - loss: 0.1227 - accuracy: 0.9586 - val_loss: 2.5028 - val_accuracy: 0.7560
# Epoch 16/50
# 68/68 [==============================] - 25s 366ms/step - loss: 0.0631 - accuracy: 0.9810 - val_loss: 0.2452 - val_accuracy: 0.9048
# Epoch 17/50
# 68/68 [==============================] - 25s 369ms/step - loss: 0.0547 - accuracy: 0.9807 - val_loss: 0.1442 - val_accuracy: 0.9583
# Epoch 18/50
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0468 - accuracy: 0.9836 - val_loss: 0.1379 - val_accuracy: 0.9643
# Epoch 19/50
# 68/68 [==============================] - 25s 365ms/step - loss: 0.0220 - accuracy: 0.9935 - val_loss: 0.1697 - val_accuracy: 0.9512
# Epoch 20/50
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0525 - accuracy: 0.9836 - val_loss: 0.3657 - val_accuracy: 0.9071
# Epoch 21/50
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0335 - accuracy: 0.9887 - val_loss: 0.2669 - val_accuracy: 0.9452
# Epoch 22/50
# 68/68 [==============================] - 25s 364ms/step - loss: 0.0551 - accuracy: 0.9792 - val_loss: 0.1512 - val_accuracy: 0.9429
# Epoch 23/50
# 68/68 [==============================] - 24s 359ms/step - loss: 0.0185 - accuracy: 0.9943 - val_loss: 0.1174 - val_accuracy: 0.9631
# Epoch 24/50
# 68/68 [==============================] - 25s 363ms/step - loss: 0.0196 - accuracy: 0.9940 - val_loss: 0.1349 - val_accuracy: 0.9702
# Epoch 25/50
# 68/68 [==============================] - 24s 355ms/step - loss: 0.0230 - accuracy: 0.9935 - val_loss: 0.1331 - val_accuracy: 0.9560
# Epoch 26/50
# 68/68 [==============================] - 25s 363ms/step - loss: 0.0353 - accuracy: 0.9878 - val_loss: 0.1808 - val_accuracy: 0.9536
# Epoch 27/50
# 68/68 [==============================] - 25s 367ms/step - loss: 0.0358 - accuracy: 0.9866 - val_loss: 0.4455 - val_accuracy: 0.8810
# Epoch 28/50
# 68/68 [==============================] - 25s 365ms/step - loss: 0.0102 - accuracy: 0.9979 - val_loss: 0.1714 - val_accuracy: 0.9619
# Epoch 29/50
# 68/68 [==============================] - 25s 375ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.1890 - val_accuracy: 0.9548
# Epoch 30/50
# 68/68 [==============================] - 25s 367ms/step - loss: 0.0198 - accuracy: 0.9926 - val_loss: 0.2425 - val_accuracy: 0.9345
# Epoch 31/50
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0354 - accuracy: 0.9884 - val_loss: 0.3469 - val_accuracy: 0.9262
# Epoch 32/50
# 68/68 [==============================] - 25s 369ms/step - loss: 0.0305 - accuracy: 0.9914 - val_loss: 0.1843 - val_accuracy: 0.9369
# Epoch 33/50
# 68/68 [==============================] - 25s 360ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.2037 - val_accuracy: 0.9464
# Epoch 34/50
# 68/68 [==============================] - 25s 362ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.1465 - val_accuracy: 0.9536
# Epoch 35/50
# 68/68 [==============================] - 24s 358ms/step - loss: 0.0147 - accuracy: 0.9961 - val_loss: 0.1470 - val_accuracy: 0.9571
# Epoch 36/50
# 68/68 [==============================] - 25s 364ms/step - loss: 0.0575 - accuracy: 0.9827 - val_loss: 0.3676 - val_accuracy: 0.9202
# Epoch 37/50
# 68/68 [==============================] - 25s 365ms/step - loss: 0.0403 - accuracy: 0.9884 - val_loss: 5.8657 - val_accuracy: 0.6429
# Epoch 38/50
# 68/68 [==============================] - 25s 368ms/step - loss: 0.2544 - accuracy: 0.9336 - val_loss: 0.2900 - val_accuracy: 0.9202
# Epoch 39/50
# 68/68 [==============================] - 26s 386ms/step - loss: 0.0811 - accuracy: 0.9735 - val_loss: 0.2211 - val_accuracy: 0.9155
# Epoch 40/50
# 68/68 [==============================] - 26s 384ms/step - loss: 0.0377 - accuracy: 0.9872 - val_loss: 1.2280 - val_accuracy: 0.8333
# Epoch 41/50
# 68/68 [==============================] - 26s 388ms/step - loss: 0.0391 - accuracy: 0.9911 - val_loss: 0.0892 - val_accuracy: 0.9690
# Epoch 42/50
# 68/68 [==============================] - 26s 377ms/step - loss: 0.0302 - accuracy: 0.9923 - val_loss: 0.1089 - val_accuracy: 0.9667
# Epoch 43/50
# 68/68 [==============================] - 26s 389ms/step - loss: 0.0160 - accuracy: 0.9964 - val_loss: 0.3606 - val_accuracy: 0.9036
# Epoch 44/50
# 68/68 [==============================] - 26s 381ms/step - loss: 0.0165 - accuracy: 0.9940 - val_loss: 0.0981 - val_accuracy: 0.9679
# Epoch 45/50
# 68/68 [==============================] - 26s 379ms/step - loss: 0.0062 - accuracy: 0.9988 - val_loss: 0.1345 - val_accuracy: 0.9583
# Epoch 46/50
# 68/68 [==============================] - 26s 383ms/step - loss: 0.0093 - accuracy: 0.9964 - val_loss: 0.0952 - val_accuracy: 0.9786
# Epoch 47/50
# 68/68 [==============================] - 26s 379ms/step - loss: 0.0050 - accuracy: 0.9982 - val_loss: 0.1508 - val_accuracy: 0.9631
# Epoch 48/50
# 68/68 [==============================] - 26s 382ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.4512 - val_accuracy: 0.9310
# Epoch 49/50
# 68/68 [==============================] - 25s 375ms/step - loss: 0.0288 - accuracy: 0.9923 - val_loss: 0.1353 - val_accuracy: 0.9536
# Epoch 50/50
# 68/68 [==============================] - 26s 384ms/step - loss: 0.0204 - accuracy: 0.9935 - val_loss: 0.3289 - val_accuracy: 0.9202

# %% [markdown]
# ## Visualize Training Results

# %%
acc = history3.history['accuracy']
val_acc = history3.history['val_accuracy']

loss = history3.history['loss']
val_loss = history3.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(30, 20))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# PLot the confusion matrix

# %%
actual2,predicted2=get_actual_predicted_labels(val_ds,model3)
plot_confusion_matrix(actual2,predicted2,class_names,'Validation')
# Out:
# 17/17 [==============================] - 3s 75ms/step

# %% [markdown]
# Print the name of the model, accuracy, class-wise precision, recall, and F1 score.

# %%
print(
    f"Classification report for classifier {model3}:\n"
    f"{classification_report(actual2,predicted2)}\n"
)
# Out:
# Classification report for classifier <keras.engine.sequential.Sequential object at 0x0000021E51A83D00>:
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.89       169
#            1       0.95      0.87      0.91       218
#            2       0.99      0.83      0.90       154
#            3       0.92      1.00      0.96       299
#
#     accuracy                           0.92       840
#    macro avg       0.93      0.91      0.91       840
# weighted avg       0.92      0.92      0.92       840

# %% [markdown]
# ## Save model3

# %%
model3.save('model/m3')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 82). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model/m3\assets
# INFO:tensorflow:Assets written to: model/m3\assets

# %% [markdown]
# ## Loading the previously saved model

# %% [markdown]
# Load the model using `tf.keras.models.load_model()` function and passing the location of the directory where the model is stored as a string, the case of this notebook, it will be stored in 'model/m3' and that is where the transfer learning model is loaded from and the architecture can be viewed by using the summary() utility of the `keras.engine.sequential.Sequential` object

# %%
new_model = tf.keras.models.load_model('model/m3')

# %%
new_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 2, 2, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  outputs (Dense)             (None, 4)                 5124
#
# =================================================================
# Total params: 4,054,695
# Trainable params: 4,012,672
# Non-trainable params: 42,023
# _________________________________________________________________

# %% [markdown]
# loss and accuracy can be verified by evaluating the model over the loaded dataset (train_ds) by using the evaluate() utility of the `keras.engine.sequential.Sequential` object

# %%
loss, acc = new_model.evaluate(train_ds, verbose=2)
print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))
# Out:
# C:\Users\agams\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 68/68 - 6s - loss: 0.1310 - accuracy: 0.9565 - 6s/epoch - 93ms/step
# Restored model, accuracy: 95.65%
